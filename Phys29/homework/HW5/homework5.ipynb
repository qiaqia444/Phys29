# %% [markdown]
# # Qia Wang HW5

# %% [markdown]
# <h1 style="font-size: 32px; text-align: center;">Introduction to Computer Programming for the Physical Sciences</h1>
# <h2 style="font-size: 24px; text-align: center;">Joseph F. Hennawi</h2>
# <h3 style="font-size: 24px; text-align: center;">Winter 2024</h2>

# %% [markdown]
# <ul style="list-style: none;">
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a new Jupyter notebook</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Name your notebook with your name and Homework 1</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a Markdown cell at the top and write your name and Homework 1</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a Markdown cell before each problem and write e.g. Problem 1, Problem 2(a), etc.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Please abide by the <b><a href="https://github.com/enigma-igm/Phys29/blob/main/using_AI_tools.md">Policy and Guidelines on Using AI Tools</a></b></li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Once you finish the problems: 1) Restart the Python kernel and clear all cell outputs. 2) Rerun the notebook from start to finish so that all answers/outputs show up. 3) Save your notebook as a single .pdf file and upload it to Gradescope on Canvas by the deadline. <b>No late homeworks will be accepted except for illness accompanied by a doctor's note.</b></li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span> For parts of problems that require analytical solutions you can perform your calculations using a pencil and paper. Then  photograph your work and convert the photograph to a .pdf file using an online tool. Homework assignments can only be submitted as a single .pdf file, so you will also need to figure out how to concatenate your photo .pdf file and your notebook .pdf file into a single .pdf file that you can submit. Online websites can do this for you. Alternatively, you can code up the analytical solution to your problems in a notebook Markdown cell using the LaTeX mathematical rendering language. This is harder but a chatbot can help you learn it. </li>
# </ul>

# %% [markdown]
# # Homework 5

# %% [markdown]
# ## Problem 1: Riemann Sums
#
# In an upcoming lecture we will learn how to numerically integrate functions in Python. You are all familiar with the concept that an integral
# $$
# I = \int_a^b f(x) dx
# $$
# is simply the area under the curve $f(x)$ between $x=a$ and $x=b$. You are probably also familiar with the definition of a Riemann integral
# that approximates this area as a finite sum of vertical rectangular strips, and then taking the limit as the width of the strips goes to zero
# (you can read more at the Wikipedia article on [Riemann sums](https://en.wikipedia.org/wiki/Riemann_sum)).
# If we use $n$ strips of equal width $\Delta x = (b-a)/n$, then the Riemann integral can be defined as
# $$
# I \approx \sum_{i=1}^n f(a + i \Delta x/2) \Delta x
# $$
# where $f(a + i \Delta x/2)$ is the value of the function $f(x)$ at the midpoint of the $i$ th strip. In other words, we are using the so-called
# **midpoint** rule whereby one evaluates the function, $f(x)$, at the midpoint of each interval, which determines the height of each rectangle.
#
# **a)** Write a function to evaluate Riemann sums that is consistent with the docstring below. **No loops are allowed anywhere in your implementation!**
#
#
# ```python
# def riemann_sum(func, a, b, n=15, plot=True):
#     """
#     Compute the Riemann sum of func(x) over the interval [a, b] with n subintervals using the midpoint rule.
#
#     Parameters
#     ----------
#     func : callable
#         The function to integrate, with calling sequence func(x).
#     a : float
#         The lower limit of integration.
#     b : float
#         The upper limit of integration.
#     n : int, optional
#         The number of subintervals to use. Default is 15.
#     plot : bool, optional
#         If True, plot the function func(x) over the interval [a, b] (using a finely spaced array of x-values), as well as the rectangles
#         used to compute the Riemann sum and the midpoints.  Default is True.
#
#     Returns
#     -------
#     answer : float
#         The estimate of the integral of func(x) over the interval [a, b].
#
#     """
# ```
#
# **b)**
# Use your `riemann_sum` function to numerically evaluate the following two definite integrals:
# $$
# \int_0^\pi \sin(x) dx = 2  \quad\quad \text{and} \quad\quad \int_{-1}^2 x^3 dx = \frac{15}{4}.
# $$
# for the default value of `n=15`. For each integral, print the numerical result, the exact result, and the relative error between the two the screen. Run your function with `plot=True` for both cases. An example of how the plot should look for the case of $\int_{-1}^{1} x^2 dx = \frac{2}{3}$ is shown below. Make sure your plot looks the same!
#
# <img src="figures/riemann_sum.png"/>
#
# **c)** Obviously the accuracy of the Riemann sum depends on the number of subintervals chosen $n$. One can show that the *absolute error*,  $\epsilon_{\rm abs}(n)$, of an integral approximated with Riemann sums scales like:
# $$
# \epsilon_{\rm abs}(n) \equiv \left| I(n) -\int_a^b f(x) dx \right| \propto n^{\alpha}
# $$
# where $\alpha$ is a constant.  For the case of $\int_0^\pi \sin(x) dx = 2$, use your function to compute the Rieman sum for $n=10, 100, 1000, 10000, 100000$ and store your results in a `numpy` array or a list. I strongly recommend that you set `plot=False` in your calls to `riemann_sum` for this step! Make a **scatter** plot (i.e. the data should be shown as points, not a curve!) of the absolute error $\epsilon_{\rm abs}(n)$ as a function of $n$ with logarithmic x and y axes. From your plot of the data, estimate the value of $\alpha$ and overplot a curve with $g(n)=A n^\alpha$, where the constant $A$ is chosen to roughly go through your data points. Make sure you label your coordinate axes and include a legend. You are allowed to use a loop over $n$ for this step.

# %%
# a)
import matplotlib.pyplot as plt
import numpy as np
def riemann_sum(func, a, b, n = 15, plot = True):
    dx = (b - a) / n # Width of the subintervals
    midpoints = np.linspace(a + dx/2, b - dx/2, n) # Midpoints of the subintervals
    answer = np.sum(func(midpoints) * dx) # Riemann sum

    if plot: # If plot is True, plot the plot
        x = np.linspace(a, b, 1000) # x-values for the function plot
        y = func(x) # y-values for the function plot

        plt.figure(figsize=(8, 6)) 
        plt.plot(x, y, 'r', linewidth = 2, label = 'f(x)', color = 'blue') # Plot the function
        plt.bar(midpoints, func(midpoints), width = dx, alpha = 0.5, align = 'center', edgecolor = 'black', label = 'Rectangles', color = 'orange') # Plot the rectangles
        plt.plot(midpoints, func(midpoints), 'bo', label = 'Midpoints', color = 'red') # Plot the midpoints
        plt.title('Riemann sum approximation of integral')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.legend()
        plt.show()
    return answer

# %%
# b)
def f(x):
    return x ** 3
print(riemann_sum(np.sin, 0, np.pi, n = 15))
print(riemann_sum(f, -1, 2, n = 15))
# Out:
# /var/folders/sj/5j1ch75533d7g5jxl3jnnff40000gn/T/ipykernel_14557/3819531803.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, y, 'r', linewidth = 2, label = 'f(x)', color = 'blue') # Plot the function
# /var/folders/sj/5j1ch75533d7g5jxl3jnnff40000gn/T/ipykernel_14557/3819531803.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(midpoints, func(midpoints), 'bo', label = 'Midpoints', color = 'red') # Plot the midpoints
# 2.0036600911565396
# 3.734999999999999

# %%
# c)
def func(x):
    return np.sin(x)
exact_integral = 2
n_values = np.array([10, 100, 1000, 10000, 100000]) # Values of n to use

errors = np.empty_like(n_values, dtype = float) # create a empty array with the same shape as n_values
for i, n in enumerate(n_values):
    estimate = riemann_sum(func, 0, np.pi, n, plot = False) # Compute the Riemann sum
    errors[i] = np.abs(estimate - exact_integral) # Absolute error of the estimate

alpha = -np.polyfit(np.log(n_values), np.log(errors), 1)[0] # slope of the best fits line in the log-log plot

A = errors[0] / n_values[0] ** alpha  # Choose A so that g(n) goes through the first data point, A is positive
g_values = A * n_values ** alpha # g(n) = A * n ^ alpha

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.loglog(n_values, errors, 'bo', label = 'Absolute error')
plt.loglog(n_values, g_values, 'r-', label = f'g(n) = {A:.2e} n^{alpha:.2f}')
plt.xlabel('n')
plt.ylabel('Absolute error')
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 2: Blackbody Radiation
#
# A *blackbody* is a physics idealization of a body in which electromagnetic radiation has come into perfect thermal equilibrium with the body, both of which can
# therefore be characterized by a  temperature $T$, assumed to be measured on the absolute (Kelvin) scale. Your own body radiates mostly infrared photons that are
# approximately blackbody in nature,  and the Sun radiates mostly optical photons that are also approximately blackbody in nature. The frequency spectrum of the
# radiation emitted by a blackbody of temperature $T$ is given by
# $$
# F(\nu) = \frac{2\pi h\nu^3}{c^2} \frac{1}{\exp(h\nu/k_{\rm B}T) - 1}
# $$
# where $h$ is Planck's constant, $\nu$ is the photon frequency, $c$ is the speed of light, and $k_{\rm B}$ is Boltzmann's constant. The quantity $F(\nu) d\nu$ is the
# radiation flux (power per unit area) emitted within the frequency range $\nu$ to $\nu + d\nu$. Therefore $F(\nu)$ has SI units of ${\rm W/m^2/Hz}$.
#
# **a)** By Taylor expanding the exponential term in the denominator of the above expression, show that in the low frequency limit $h\nu \ll k_{\rm B}T$ the radiation
# flux has a power-law dependendce on frequency. What is that power-law index? This is known as the *Rayleigh-Jeans* spectrum, and is what classical physics predicted for the spectrum before the advent of quantum mechanics. You should see that Planck's constant does not appear in your answer (hence there is no quantum physics in this description).
#
# **b)** Write a Python function that takes as input the temperature $T$ and a frequency $\nu$ and returns the radiation flux $F(\nu)$. Given the large
# dynamic range of frequency, $\nu$, that you will need to visualize in part **c)**, you should evaluate this function using a `numpy` array of **logarithmically spaced** $\nu$ values.
#
# **c)** Plot the spectrum (i.e. $F(\nu)$ vs. $\nu$) for the case of $T = 310.15\,{\rm K}$ (human body temperature) and $T = 5778\,{\rm K}$ (Sun's surface temperature) *on the same plot*.  Your plot
# should have the following set of characteristics:
# - Different colors for the curves illustrating the two different temperatures.
# - Labels on the $x$ and $y$ axes (specifying units).
# - A legend indicating the two different curves.
# - Clearly illustrate the behavior at low and high frequencies. This requires a sufficiently large range of frequencies and logarithmic axes for both the $x$ and $y$ axes.
# - A secondary $x$-axis at the top of the plot that shows the wavelength $\lambda = c/\nu$ in microns, $\mu{\rm m}$. Recall that $1\mu{\rm m} = 10^{-6}{\rm m}$.
# - A reference curve shown as a black dashed-line that shows the Rayleigh-Jeans power-law behavior that you derived for the low frequency limit in part **a)**. Assume the Sun's surface temperature, $T=5778\,{\rm K}$, for plotting this Rayleigh-Jeans power-law curve.
#
# **d)** Is the low-frequency behavior of the spectrum consistent with the Rayleigh-Jeans power-law you derived in part **a)**? Does the human body spectral flux ever exceed that of the Sun at any frequency?

# %%
# a)
c = 3 * 10 ** 8
h = 6.626 * 10 ** -34
k = 1.38 * 10 ** -23
v = np.logspace(1, 20, 1000)

# taylor expansion of e^x = 1 + x + x^2 / 2 + x^3 / 6 + ...
taylor_expansion = lambda T: 2 * np.pi * h * v ** 3 / (c ** 2 * (1 + h * v / k / T + (h * v / k / T) ** 2 / 2 + (h * v / k / T) ** 3 / 6))
# at low frequency limit hv << kT, the Taylor expansion of the exponential function can be used to approximate the radiation flux
rayleigh_jeans = lambda T: 2 * np.pi * v ** 2 * k * T / c ** 2
# power law index is 2
print(rayleigh_jeans)
# Out:
# <function <lambda> at 0x7fa4df9e7d30>

# %%
# b)
def radiation_flux(v, T):
    return 2 * np.pi * h * v ** 3 / (c ** 2 * (np.exp(h * v / k / T) - 1))
def rayleigh_jeans(v, T):
    return 2 * np.pi * v ** 2 * k * T / c ** 2

# %%
# c)
human_T = 310.15
sun_T = 5778
wavelength = c / v * 1e6

plt.figure(figsize=(8, 6))
human_F = radiation_flux(v, human_T)
sun_F = radiation_flux(v, sun_T)
sun_F_rayleigh_jeans = rayleigh_jeans(v, sun_T)

# Plot the figure
fig, ax1 = plt.subplots()
ax1.plot(v, human_F, 'r', label=f'Human body (T = {human_T} K)')
ax1.plot(v, sun_F, 'b', label=f'Sun (T = {sun_T} K)')
ax1.plot(v, sun_F_rayleigh_jeans, color='black', linestyle='dashed', label='Rayleigh-Jeans approximation')
ax1.legend()
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Frequency (Hz)')
ax1.set_ylabel('Radiation flux')
ax1.set_title('Blackbody Radiation Spectrum')

ax2 = ax1.twiny()  # Create a second x-axis
ax2.set_xlim(wavelength.min(), wavelength.max())  # Set the limits of the second x-axis
ax2.set_xscale('log')  # Set the scale of the second x-axis to be logarithmic
ax2.set_xlabel('Wavelength (um)')  # Label the second x-axis
plt.tight_layout()

plt.show()
# Out:
# /var/folders/sj/5j1ch75533d7g5jxl3jnnff40000gn/T/ipykernel_14557/1196352270.py:3: RuntimeWarning: overflow encountered in exp
#   return 2 * np.pi * h * v ** 3 / (c ** 2 * (np.exp(h * v / k / T) - 1))
# /var/folders/sj/5j1ch75533d7g5jxl3jnnff40000gn/T/ipykernel_14557/1196352270.py:3: RuntimeWarning: overflow encountered in multiply
#   return 2 * np.pi * h * v ** 3 / (c ** 2 * (np.exp(h * v / k / T) - 1))

# %%
# d)
# for the low frequency limit, the Rayleigh-Jeans approximation is a good approximation to the radiation flux. the curves are close to each other at low frequency.

# %% [markdown]
# # Problem 3: Distribution of Household Size and Income in the US
#
# The [American Community Survey](https://www.census.gov/programs-surveys/acs) (ACS) is a yearly survey conducted by the United States Census Bureau that collects information about the country and its inhabitants.  Download the file [census_income_data.csv](https://github.com/enigma-igm/Phys29/blob/main/Phys29/homework/HW5/data/census_income_data.csv) at this link: https://github.com/enigma-igm/Phys29/blob/main/Phys29/homework/HW4/data/census_income_data2022.csv This is a comma-separated values or **csv** file containing household income data from the ACS.
#
# As you can see from the header, it has three columns, `WGTP`, `NPF`, and `HINCP`:
# - `WGTP` is the weight of the household, or the number of such households in the US population
# - `NPF` is the number of people in the household
# - `HINCP` is the household income
#
# The `WGTP` is a statistical weight that is assigned to each record (line of the file) that indicates how many people in the population are represented by that record.  In yearly surveys like the ACS, it's not feasible to collect data from every individual in the population, so a subset of the population is surveyed instead.  Each record in the datafile thus represents (or "stands in for") a certain number of similar individuals in the population. The WGTP value tells you how many individuals that record represents.
#
# For example a line in the file like:
# ```
# WGTP, NPF, HINCP
# 127, 5, 75000
# ```
# indicates that in the USA there are 127 households with 5 members per household in them which earn a yearly household income of $75,000.
#
# In this problem we want to analyze the distribution of household size and household income in the U.S. population. Given the way that the data is collected, we need to use the WGTP values to get accurate estimates of the distribution across the population. For example, if you want to calculate the total number of households:
# $$
# N_{\rm households} = \sum_i {\rm WGTP}_i
# $$
# where the sum is over all records in the datafile.
#
# Similarly, to calculate the total population of the USA, you would sum up the product of the WGTP (# of similar housholds in USA) and NPF (# of family members per household) values:
# $$
# N_{\rm people} = \sum_i {\rm WGTP}_i \times {\rm NPF}_i.
# $$

# %% [markdown]
# **a)** Read in the datafile into a `pandas` DataFrame `df`. Run the `df.describe()` method on the DataFrame to get a sense of the values in the data.
#
# **b)** Assign the `WGTP`, `NPF`, and `HINCP` columns to `numpy` arrays. Calculate the total number of households and the total number of people in the US population using the formulas above.  Print the results to the screen. Do the numbers you get make sense?
#
# **c)** According to your result from `df.describe()`, the household income column, `HINCP`, contains negative values. These correspond to households that had a net loss in 2022. For example, suppose a household member owns a business that suffered a loss in 2022 (the business expenses exceeded business income), this would corresopnd to a net negative income. Use `numpy` boolean array indexing to create a new filtered dataset that only includes the records with a net positive household income, i.e. `HINCP > 0`. Recompute the total number of households and the total number of people in the US population using this filtered dataset and print the results to the screen. Use this filtered dataset for all the remaining parts of this problem.
#
# **d)** In lecture we learned how `matplotlib` histograms can be used to visualize the distribution in a dataset. Use the `matplotlib` library to create a histogram of the number of persons per household, `NPF` in the dataset. Choose linearly spaced bins of unit width from the minimum value of the `NPF` to the maximum value (make sure your bins include the minimum and maximum value). The $y$-axis of your histogram **should be the percentage of the total number of housholds** contained in each bin, where the total number of households is the number you calculated in part **c)**. Note that you cannot simply run `plt.hist(NPF, bins=bins)` or `np.histogram(NPF, bins=bins)` because the `WGTP` values need to be taken into account. The `plt.hist` and `np.histogram` functions have a `weights` argument that you can use to construct weighted histogram and thus factor in the weights. Use the arrays returned by the histogram function to explicitly verify that the sum of the percentages over all the bins is equal to 100%, and print this to the screen.
#
# **e)** Create and plot a histogram of the household income, `HINCP` in the dataset, again taking proper account of the `WGTP` weights.  Choose linearly spaced bins of width $\$20,000$ spanning from $\$0$ to $\$2,500,000$. As in part **d)**, the $y$-axis should be the percentage of the total number of housholds contained in each bin. Choose a linear scaling for both the $x$-axis and $y$-axis.  Again, verify that the sum of the percentages over all the bins is equal to 100%, and print this to the screen.
#
# **f)** Remake the plot from part **e)** but using a logarithmic scale for the $y$-axis. Which scale do you think is more informative, linear or log?
#
# **g)** For the household income histogram, write code that uses the arrays returned to print to the screen the bin index (zero based), the left edge of the bin, the right edge of the bin, and the percentage (up to six decimal places) of the total number of households contained in each bin.
#
# **h)** From the `numpy` array that contains the household income histogram output (i.e. what `np.histogram` or `plt.hist` return), compute the **total percentage** of households with an income **greater than or equal to** $\$500,000$ and print this to the screen.
#
# **i)** From the `numpy` arrays that contain the US census data (i.e. `WGPT`, `HINCP` etc.), directly compute the the **total percentage** of households with an income **greater than or equal to** $\$500,000$ and print this to the screen.  **Note that you are not allowed to use your histogram outputs for this step**, i.e. your code needs to operate on the census data `numpy` arrays directly.  Verify that that the two percentages you computed in parts **f)** and **g)** are in agreement with each other.

# %%
# a)
import pandas as pd
# use the pandas library to read the data from the csv file
df = pd.read_csv('data/census_income_data_2022.csv')
WGTP = pd.DataFrame(df['WGTP'])
NPF = pd.DataFrame(df['NPF'])
HINCP = pd.DataFrame(df['HINCP'])
df.describe()
# Out:
#                WGTP           NPF         HINCP  Unnamed: 3
# count  1.611650e+06  1.611650e+06  1.611650e+06         0.0
# mean   8.920851e+01  2.053273e+00  7.552088e+04         NaN
# std    8.848104e+01  1.344968e+00  1.237117e+05         NaN
# min    0.000000e+00  1.000000e+00 -6.000000e+04         NaN
# 25%    3.700000e+01  1.000000e+00  1.470000e+04         NaN
# 50%    6.700000e+01  2.000000e+00  5.700000e+04         NaN
# 75%    1.120000e+02  3.000000e+00  1.142000e+05         NaN
# max    2.339000e+03  1.800000e+01  2.481200e+06         NaN

# %%
# b)
WGTP_array = np.array(WGTP)
NPF_array = np.array(NPF)
HINCP_array = np.array(HINCP)
total_number_households = np.sum(WGTP_array) # total number of households by using the formula provided
total_number_people = np.sum(NPF_array * WGTP_array) # total number of people by using the formula provided
print(f'Total number of households: {total_number_households}')
print(f'Total number of people: {total_number_people}')

# this make sense for the total number of people is larger than the total number of households
# Out:
# Total number of households: 143772895
# Total number of people: 314293387

# %%
# c)
HINCP_postive = HINCP_array[HINCP_array > 0] # select the positive values of HINCP
WGTP_with_positive_HINCP = WGTP_array[HINCP_array > 0] # select the corresponding WGTP values
NPF_with_positive_HINCP = NPF_array[HINCP_array > 0] # select the corresponding NPF values
total_number_households = np.sum(WGTP_with_positive_HINCP) # total number of households with positive HINCP
total_number_people = np.sum(NPF_with_positive_HINCP * WGTP_with_positive_HINCP) # total number of people with positive HINCP
print(f'Total number of households: {total_number_households}')
print(f'Total number of people: {total_number_people}')
# Out:
# Total number of households: 127970381
# Total number of people: 297334150

# %%
# d)
bins = np.arange(NPF_with_positive_HINCP.min(), NPF_with_positive_HINCP.max() + 1) # Create the bins
weights = WGTP_with_positive_HINCP / total_number_households * 100 # Compute the weights
counts, bin_edges, patches = plt.hist(NPF_with_positive_HINCP, bins = bins, weights = weights, edgecolor='black')

print(f'Sum of percentages: {counts.sum():.2f}%') # Sum of the percentages to check if it is 100%

# plot the histogram
plt.xlabel('Number of persons per household')
plt.ylabel('Percentage of households (%)')
plt.show()
# Out:
# Sum of percentages: 100.00%

# %%
# e)
bins = np.arange(0, 2500000, 20000) # Create the bins
counts, bin_edges, patches = plt.hist(HINCP_postive, bins = bins, weights = weights, edgecolor='black') # Plot the histogram

print(f'Sum of percentages: {counts.sum():.2f}%') # sum of the percentages to check if it is 100%
# plot the histogram
plt.xlabel('Household income (USD)')
plt.xscale('linear')
plt.ylabel('Percentage of households (%)')
plt.show()
# Out:
# Sum of percentages: 100.00%

# %%
# f)
bins = np.arange(0, 2500000, 20000)
weights = WGTP_with_positive_HINCP / total_number_households * 100
counts, bin_edges, patches = plt.hist(HINCP_postive, bins = bins, weights = weights, edgecolor='black')

print(f'Sum of percentages: {counts.sum():.2f}%')
plt.xlabel('Household income (USD)')
plt.ylabel('Percentage of households (%)')
plt.yscale('log')
plt.show()
# Out:
# Sum of percentages: 100.00%

# %%
# g)
# Create the histogram and get the counts and bin edges
counts, bin_edges = np.histogram(HINCP_postive, bins = bins, weights = weights)

# Iterate over the bins
for i in range(len(counts)):
    # Print the bin index, left edge, right edge, and percentage
    print(f'Bin index: {i}, Left edge: {bin_edges[i]}, Right edge: {bin_edges[i+1]}, Percentage: {counts[i]:.6f}%')
# Out:
# Bin index: 0, Left edge: 0, Right edge: 20000, Percentage: 11.529703%
# Bin index: 1, Left edge: 20000, Right edge: 40000, Percentage: 15.076321%
# Bin index: 2, Left edge: 40000, Right edge: 60000, Percentage: 14.533393%
# Bin index: 3, Left edge: 60000, Right edge: 80000, Percentage: 12.597338%
# Bin index: 4, Left edge: 80000, Right edge: 100000, Percentage: 10.153553%
# Bin index: 5, Left edge: 100000, Right edge: 120000, Percentage: 8.111432%
# Bin index: 6, Left edge: 120000, Right edge: 140000, Percentage: 6.163672%
# Bin index: 7, Left edge: 140000, Right edge: 160000, Percentage: 4.669413%
# Bin index: 8, Left edge: 160000, Right edge: 180000, Percentage: 3.495962%
# Bin index: 9, Left edge: 180000, Right edge: 200000, Percentage: 2.646079%
# Bin index: 10, Left edge: 200000, Right edge: 220000, Percentage: 2.148675%
# Bin index: 11, Left edge: 220000, Right edge: 240000, Percentage: 1.504892%
# Bin index: 12, Left edge: 240000, Right edge: 260000, Percentage: 1.202633%
# Bin index: 13, Left edge: 260000, Right edge: 280000, Percentage: 0.871540%
# Bin index: 14, Left edge: 280000, Right edge: 300000, Percentage: 0.647785%
# Bin index: 15, Left edge: 300000, Right edge: 320000, Percentage: 0.610378%
# Bin index: 16, Left edge: 320000, Right edge: 340000, Percentage: 0.441285%
# Bin index: 17, Left edge: 340000, Right edge: 360000, Percentage: 0.386533%
# Bin index: 18, Left edge: 360000, Right edge: 380000, Percentage: 0.297481%
# Bin index: 19, Left edge: 380000, Right edge: 400000, Percentage: 0.249398%
# Bin index: 20, Left edge: 400000, Right edge: 420000, Percentage: 0.254275%
# Bin index: 21, Left edge: 420000, Right edge: 440000, Percentage: 0.197551%
# Bin index: 22, Left edge: 440000, Right edge: 460000, Percentage: 0.174890%
# Bin index: 23, Left edge: 460000, Right edge: 480000, Percentage: 0.147469%
# Bin index: 24, Left edge: 480000, Right edge: 500000, Percentage: 0.181207%
# Bin index: 25, Left edge: 500000, Right edge: 520000, Percentage: 0.163471%
# Bin index: 26, Left edge: 520000, Right edge: 540000, Percentage: 0.156765%
# Bin index: 27, Left edge: 540000, Right edge: 560000, Percentage: 0.147565%
# Bin index: 28, Left edge: 560000, Right edge: 580000, Percentage: 0.131069%
# Bin index: 29, Left edge: 580000, Right edge: 600000, Percentage: 0.112678%
# Bin index: 30, Left edge: 600000, Right edge: 620000, Percentage: 0.104666%
# Bin index: 31, Left edge: 620000, Right edge: 640000, Percentage: 0.092410%
# Bin index: 32, Left edge: 640000, Right edge: 660000, Percentage: 0.071291%
# Bin index: 33, Left edge: 660000, Right edge: 680000, Percentage: 0.056112%
# Bin index: 34, Left edge: 680000, Right edge: 700000, Percentage: 0.089286%
# Bin index: 35, Left edge: 700000, Right edge: 720000, Percentage: 0.065552%
# Bin index: 36, Left edge: 720000, Right edge: 740000, Percentage: 0.045936%
# Bin index: 37, Left edge: 740000, Right edge: 760000, Percentage: 0.038659%
# Bin index: 38, Left edge: 760000, Right edge: 780000, Percentage: 0.068040%
# Bin index: 39, Left edge: 780000, Right edge: 800000, Percentage: 0.039886%
# Bin index: 40, Left edge: 800000, Right edge: 820000, Percentage: 0.031867%
# Bin index: 41, Left edge: 820000, Right edge: 840000, Percentage: 0.029045%
# Bin index: 42, Left edge: 840000, Right edge: 860000, Percentage: 0.025745%
# Bin index: 43, Left edge: 860000, Right edge: 880000, Percentage: 0.022640%
# Bin index: 44, Left edge: 880000, Right edge: 900000, Percentage: 0.017711%
# Bin index: 45, Left edge: 900000, Right edge: 920000, Percentage: 0.020551%
# Bin index: 46, Left edge: 920000, Right edge: 940000, Percentage: 0.015520%
# Bin index: 47, Left edge: 940000, Right edge: 960000, Percentage: 0.011661%
# Bin index: 48, Left edge: 960000, Right edge: 980000, Percentage: 0.013391%
# Bin index: 49, Left edge: 980000, Right edge: 1000000, Percentage: 0.013500%
# Bin index: 50, Left edge: 1000000, Right edge: 1020000, Percentage: 0.010850%
# Bin index: 51, Left edge: 1020000, Right edge: 1040000, Percentage: 0.007438%
# Bin index: 52, Left edge: 1040000, Right edge: 1060000, Percentage: 0.009289%
# Bin index: 53, Left edge: 1060000, Right edge: 1080000, Percentage: 0.008296%
# Bin index: 54, Left edge: 1080000, Right edge: 1100000, Percentage: 0.008264%
# Bin index: 55, Left edge: 1100000, Right edge: 1120000, Percentage: 0.006628%
# Bin index: 56, Left edge: 1120000, Right edge: 1140000, Percentage: 0.005719%
# Bin index: 57, Left edge: 1140000, Right edge: 1160000, Percentage: 0.006116%
# Bin index: 58, Left edge: 1160000, Right edge: 1180000, Percentage: 0.008073%
# Bin index: 59, Left edge: 1180000, Right edge: 1200000, Percentage: 0.004769%
# Bin index: 60, Left edge: 1200000, Right edge: 1220000, Percentage: 0.003306%
# Bin index: 61, Left edge: 1220000, Right edge: 1240000, Percentage: 0.003067%
# Bin index: 62, Left edge: 1240000, Right edge: 1260000, Percentage: 0.002970%
# Bin index: 63, Left edge: 1260000, Right edge: 1280000, Percentage: 0.003281%
# Bin index: 64, Left edge: 1280000, Right edge: 1300000, Percentage: 0.003286%
# Bin index: 65, Left edge: 1300000, Right edge: 1320000, Percentage: 0.001812%
# Bin index: 66, Left edge: 1320000, Right edge: 1340000, Percentage: 0.001926%
# Bin index: 67, Left edge: 1340000, Right edge: 1360000, Percentage: 0.000887%
# Bin index: 68, Left edge: 1360000, Right edge: 1380000, Percentage: 0.003952%
# Bin index: 69, Left edge: 1380000, Right edge: 1400000, Percentage: 0.001868%
# Bin index: 70, Left edge: 1400000, Right edge: 1420000, Percentage: 0.001533%
# Bin index: 71, Left edge: 1420000, Right edge: 1440000, Percentage: 0.001359%
# Bin index: 72, Left edge: 1440000, Right edge: 1460000, Percentage: 0.001643%
# Bin index: 73, Left edge: 1460000, Right edge: 1480000, Percentage: 0.000851%
# Bin index: 74, Left edge: 1480000, Right edge: 1500000, Percentage: 0.000951%
# Bin index: 75, Left edge: 1500000, Right edge: 1520000, Percentage: 0.001468%
# Bin index: 76, Left edge: 1520000, Right edge: 1540000, Percentage: 0.003759%
# Bin index: 77, Left edge: 1540000, Right edge: 1560000, Percentage: 0.000756%
# Bin index: 78, Left edge: 1560000, Right edge: 1580000, Percentage: 0.001347%
# Bin index: 79, Left edge: 1580000, Right edge: 1600000, Percentage: 0.000835%
# Bin index: 80, Left edge: 1600000, Right edge: 1620000, Percentage: 0.000391%
# Bin index: 81, Left edge: 1620000, Right edge: 1640000, Percentage: 0.000347%
# Bin index: 82, Left edge: 1640000, Right edge: 1660000, Percentage: 0.000602%
# Bin index: 83, Left edge: 1660000, Right edge: 1680000, Percentage: 0.000349%
# Bin index: 84, Left edge: 1680000, Right edge: 1700000, Percentage: 0.000173%
# Bin index: 85, Left edge: 1700000, Right edge: 1720000, Percentage: 0.000184%
# Bin index: 86, Left edge: 1720000, Right edge: 1740000, Percentage: 0.000038%
# Bin index: 87, Left edge: 1740000, Right edge: 1760000, Percentage: 0.000124%
# Bin index: 88, Left edge: 1760000, Right edge: 1780000, Percentage: 0.000423%
# Bin index: 89, Left edge: 1780000, Right edge: 1800000, Percentage: 0.000009%
# Bin index: 90, Left edge: 1800000, Right edge: 1820000, Percentage: 0.000084%
# Bin index: 91, Left edge: 1820000, Right edge: 1840000, Percentage: 0.000117%
# Bin index: 92, Left edge: 1840000, Right edge: 1860000, Percentage: 0.000089%
# Bin index: 93, Left edge: 1860000, Right edge: 1880000, Percentage: 0.000098%
# Bin index: 94, Left edge: 1880000, Right edge: 1900000, Percentage: 0.000279%
# Bin index: 95, Left edge: 1900000, Right edge: 1920000, Percentage: 0.000361%
# Bin index: 96, Left edge: 1920000, Right edge: 1940000, Percentage: 0.000421%
# Bin index: 97, Left edge: 1940000, Right edge: 1960000, Percentage: 0.000081%
# Bin index: 98, Left edge: 1960000, Right edge: 1980000, Percentage: 0.000041%
# Bin index: 99, Left edge: 1980000, Right edge: 2000000, Percentage: 0.000170%
# Bin index: 100, Left edge: 2000000, Right edge: 2020000, Percentage: 0.000230%
# Bin index: 101, Left edge: 2020000, Right edge: 2040000, Percentage: 0.000134%
# Bin index: 102, Left edge: 2040000, Right edge: 2060000, Percentage: 0.000000%
# Bin index: 103, Left edge: 2060000, Right edge: 2080000, Percentage: 0.000459%
# Bin index: 104, Left edge: 2080000, Right edge: 2100000, Percentage: 0.000113%
# Bin index: 105, Left edge: 2100000, Right edge: 2120000, Percentage: 0.000037%
# Bin index: 106, Left edge: 2120000, Right edge: 2140000, Percentage: 0.000044%
# Bin index: 107, Left edge: 2140000, Right edge: 2160000, Percentage: 0.000000%
# Bin index: 108, Left edge: 2160000, Right edge: 2180000, Percentage: 0.000043%
# Bin index: 109, Left edge: 2180000, Right edge: 2200000, Percentage: 0.000030%
# Bin index: 110, Left edge: 2200000, Right edge: 2220000, Percentage: 0.000000%
# Bin index: 111, Left edge: 2220000, Right edge: 2240000, Percentage: 0.000155%
# Bin index: 112, Left edge: 2240000, Right edge: 2260000, Percentage: 0.000059%
# Bin index: 113, Left edge: 2260000, Right edge: 2280000, Percentage: 0.000000%
# Bin index: 114, Left edge: 2280000, Right edge: 2300000, Percentage: 0.000000%
# Bin index: 115, Left edge: 2300000, Right edge: 2320000, Percentage: 0.000042%
# Bin index: 116, Left edge: 2320000, Right edge: 2340000, Percentage: 0.000000%
# Bin index: 117, Left edge: 2340000, Right edge: 2360000, Percentage: 0.000044%
# Bin index: 118, Left edge: 2360000, Right edge: 2380000, Percentage: 0.000000%
# Bin index: 119, Left edge: 2380000, Right edge: 2400000, Percentage: 0.000000%
# Bin index: 120, Left edge: 2400000, Right edge: 2420000, Percentage: 0.000000%
# Bin index: 121, Left edge: 2420000, Right edge: 2440000, Percentage: 0.000000%
# Bin index: 122, Left edge: 2440000, Right edge: 2460000, Percentage: 0.000000%
# Bin index: 123, Left edge: 2460000, Right edge: 2480000, Percentage: 0.000000%

# %%
# h)
index = np.where(bin_edges >= 500000)[0][0] # Find the index of the bin where the left edge is 500,000
percentage_f = counts[index:].sum() # Compute the total percentage of households with income >= 500,000
print(f'Total percentage of households with income >= $500,000 (from histogram): {percentage_f:.2f}%')
# Out:
# Total percentage of households with income >= $500,000 (from histogram): 1.71%

# %%
# i)
percentage_i = df[df['HINCP'] >= 500000]['WGTP'].sum() / total_number_households * 100 # Compute the total percentage of households with income >= 500,000 directly from the data
print(f'Total percentage of households with income >= $500,000 (from data): {percentage_i:.2f}%')
# Out:
# Total percentage of households with income >= $500,000 (from data): 1.71%
