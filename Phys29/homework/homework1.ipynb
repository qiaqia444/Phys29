# %% [markdown]
# <h1 style="font-size: 32px; text-align: center;">Introduction to Computer Programming for the Physical Sciences</h1>
# <h2 style="font-size: 24px; text-align: center;">Joseph F. Hennawi</h2>
# <h3 style="font-size: 24px; text-align: center;">Winter 2024</h2>
#
# <h3 style="font-size: 32px; text-align: left; font-weight: bold;">Homework 1</h3>

# %% [markdown]
# <ul style="list-style: none;">
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a new Jupyter notebook</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Name your notebook with your name and Homework 1</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a Markdown cell at the top and write your name and Homework 1</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Open a Markdown cell before each problem and write e.g. Problem 1, Problem 2(a), etc.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Once you finish the problems, save your notebook as a single .pdf file and upload it to Canvas by the deadline. <b>No late homeworks will be accepted except for illness accompanied by a doctor's note.</b></li>
# </ul>

# %% [markdown]
# Spend at least 30 minutes on each problem trying to code up the answer to the problem yourself. For this "biological intelligence" coding step, you are allowed to use the internet, i.e. query Google or coding sites like StackOverflow be searched for help, but don't use AI tools. After the 20 minutes is up, if you feel like continuing on your own, feel free to do so.  But after 20 minutes you can use AI tools to assist you.
#
# If you are using AI:
#
# - Copy the problem into the prompt provided by the AI chatboth. Include the following line at the end of your prompt:  "Please do not put any comments of any kind in the code as I want to comment and document the code myself. Thank you."  This will ensure that the AI chatbot does not put any inline comments in the code.
# - Use the copy and paste feature to copy the AI generated code into your Jupyter notebook. Test the code to make sure the results make sense.
# - Now go through the code line by line to understand what the AI generated and add the inline comments explaning what the code is doing. You can ask the AI chatbot specific questions about lines of code, constructs, functions etc. It is probably useful to use Google in tandem in case you need to pull up python documentation for specific python functions or constructs.
# - Note that you can ask the AI chatbot specific questions about constructs or lines of code to assist you with the comment generation. See the example notebook from lecture.
#
# Yes, I realize that you can also ask the AI chatbot to write the code with the comments, but that would come at the expense of your own learning experience. So please don't do that! Things are going to get significantly more challenging later in the course, and you will need to learn the fundamentals of coding. In the future, the AI won't be smart enough to help you, at least not with the current generation of models!
#
# If you use AI, please cite the source in your notebook (should I require screenshots?), i.e. "Problem solved with the assistance of chatGPT".

# %%
import re

sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"

# Split the sentence into words
words = re.split(r'\W+', sentence)

# Remove any empty strings caused by split
words = [word for word in words if word]

# Count the number of words
word_count = len(words)

# Count the number of characters
char_count = len(sentence)

print(f"Number of words: {word_count}")
print(f"Number of characters: {char_count}")
# Out:
# Number of words: 52
# Number of characters: 255

# %%
import re

sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"

# Remove punctuation
sentence = re.sub(r'[^\w\s]', '', sentence)

# Split the sentence into words
words = re.split(r'\W+', sentence)

# Remove any empty strings caused by split
words = [word for word in words if word]

# Remove repeated words
words = list(set(words))

# Count the number of words
word_count = len(words)

# Count the number of characters
char_count = len(sentence)

print(f"Number of unique words: {word_count}")
print(f"Number of characters: {char_count}")
# Out:
# Number of unique words: 44
# Number of characters: 250

# %%
import re

sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"

# Remove punctuation
sentence = re.sub(r'[^\w\s]', '', sentence)

# Split the sentence into words
words = re.split(r'\W+', sentence)

# Remove any empty strings caused by split
words = [word for word in words if word]

# Remove repeated words
unique_words = list(set(words))

# Join the unique words back into a sentence
sentence_without_repeat_words = ' '.join(unique_words)

print(sentence_without_repeat_words)
# Out:
# that stubborn very and gloomy which path how the half life rough thought journey hard my renews a say aright was what ah wood our to And led it lost fear this woodland through just is wild in way found of When because I

# %%
import re

sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"

# Remove punctuation
sentence = re.sub(r'[^\w\s]', '', sentence)

# Split the sentence into words
words = re.split(r'\W+', sentence)

# Remove any empty strings caused by split
words = [word for word in words if word]

# Remove repeated words while maintaining original order
unique_words = []
[unique_words.append(word) for word in words if word not in unique_words]

# Join the unique words back into a sentence
sentence_without_repeat_words = ' '.join(unique_words)

print(sentence_without_repeat_words)
# Out:
# When half way through the journey of our life I found that was in a gloomy wood because path which led aright lost And ah how hard it is to say just what this wild and rough stubborn woodland very thought renews my fear

# %%
def count_words_and_characters(sentence):
    # Replace punctuation with spaces
    for char in ",;.!":
        sentence = sentence.replace(char, " ")

    # Split the sentence into words
    words = sentence.split()

    # Count the number of words and characters
    num_words = len(words)
    num_characters = len(sentence)

    # Print the results
    print("Number of words:", num_words)
    print("Number of characters:", num_characters)

# Test the program with the given sentence
sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"
count_words_and_characters(sentence)
# Out:
# Number of words: 52
# Number of characters: 255

# %%
def remove_repeat_words(sentence):
    # Replace punctuation with spaces
    for char in ",;.!":
        sentence = sentence.replace(char, " ")

    # Split the sentence into words
    words = sentence.split()

    # Remove repeated words
    unique_words = list(set(words))

    # Print the modified sentence without punctuation
    modified_sentence = " ".join(unique_words)
    print("Modified sentence:", modified_sentence)

# Test the program with the given sentence
sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"
remove_repeat_words(sentence)
# Out:
# Modified sentence: that stubborn very and gloomy which path how the half life rough thought journey hard my renews a say aright was what ah wood our to And led it lost fear this woodland through just is wild in way found of When because I

# %%
def remove_repeat_words(sentence):
    # Replace punctuation with spaces
    for char in ",;.!":
        sentence = sentence.replace(char, " ")

    # Split the sentence into words
    words = sentence.split()

    # Remove repeated words while maintaining the original order
    unique_words = []
    seen_words = set()
    for word in words:
        if word not in seen_words:
            unique_words.append(word)
            seen_words.add(word)

    # Print the modified sentence without punctuation
    modified_sentence = " ".join(unique_words)
    print("Modified sentence:", modified_sentence)

# Test the program with the given sentence
sentence = "When half way through the journey of our life I found that I was in a gloomy wood, because the path which led aright was lost. And ah, how hard it is to say just what this wild and rough and stubborn woodland was, the very thought of which renews my fear!"
remove_repeat_words(sentence)
# Out:
# Modified sentence: When half way through the journey of our life I found that was in a gloomy wood because path which led aright lost And ah how hard it is to say just what this wild and rough stubborn woodland very thought renews my fear

# %%
def all_even_digits(number):
    # Check if all digits in the number are even
    return all(int(digit) % 2 == 0 for digit in str(number))

# Find and print numbers with all even digits between 100 and 400
result = [num for num in range(100, 401) if all_even_digits(num)]

print("Numbers between 100 and 400 with all even digits:")
print(result)
# Out:
# Numbers between 100 and 400 with all even digits:
# [200, 202, 204, 206, 208, 220, 222, 224, 226, 228, 240, 242, 244, 246, 248, 260, 262, 264, 266, 268, 280, 282, 284, 286, 288, 400]

# %%
def prime_factors_with_powers(number):
    factors = {}
    divisor = 2

    while divisor <= number:
        count = 0
        while number % divisor == 0:
            count += 1
            number //= divisor
        if count > 0:
            factors[divisor] = count
        divisor += 1

    return factors

# Test the program with the number 9572121
number_to_factorize = 9572121
result = prime_factors_with_powers(number_to_factorize)

# Print the prime factors with their relative powers
print(f"Prime factors of {number_to_factorize} with their relative powers:")
for factor, power in result.items():
    print(f"{factor} to the power {power}")
# Out:
# Prime factors of 9572121 with their relative powers:
# 3 to the power 3
# 13 to the power 1
# 27271 to the power 1

# %%
def caesar_cipher(text, shift):
    result = ""
    for char in text:
        if char.islower():
            result += chr((ord(char) - ord('a') + shift) % 26 + ord('a'))
        elif char.isupper():
            result += chr((ord(char) - ord('A') + shift) % 26 + ord('A'))
        else:
            result += char
    return result

# Test the function with the encrypted message and a shift of 13
encrypted_message = "pbatenghyngvbaf lbh unir fhpprrqrq va qrpelcgvat gur fgevat"
decrypted_message = caesar_cipher(encrypted_message, -13)

print("Encrypted Message:", encrypted_message)
print("Decrypted Message:", decrypted_message)
# Out:
# Encrypted Message: pbatenghyngvbaf lbh unir fhpprrqrq va qrpelcgvat gur fgevat
# Decrypted Message: congratulations you have succeeded in decrypting the string

# %%
ord('a')
# Out:
# 97

# %%
for code_point in range(0, 128):
    print(f"Code Point: U+{code_point:04X}, Character: {chr(code_point)}")
# Out:
# Code Point: U+0000, Character:
# Code Point: U+0001, Character:
# Code Point: U+0002, Character:
# Code Point: U+0003, Character:
# Code Point: U+0004, Character:
# Code Point: U+0005, Character:
# Code Point: U+0006, Character:
# Code Point: U+0007, Character:
# Code Point: U+0008, Character:
# Code Point: U+0009, Character:
# Code Point: U+000A, Character:
#
# Code Point: U+000B, Character:
# Code Point: U+000C, Character:
# Code Point: U+000D, Character:
# Code Point: U+000E, Character:
# Code Point: U+000F, Character:
# Code Point: U+0010, Character:
# Code Point: U+0011, Character:
# Code Point: U+0012, Character:
# Code Point: U+0013, Character:
# Code Point: U+0014, Character:
# Code Point: U+0015, Character:
# Code Point: U+0016, Character:
# Code Point: U+0017, Character:
# Code Point: U+0018, Character:
# Code Point: U+0019, Character:
# Code Point: U+001A, Character:
# Code Point: U+001B, Character:
# Code Point: U+001C, Character:
# Code Point: U+001D, Character:
# ...

# %%
chr(98)
# Out:
# 'b'

# %%
def can_buy(nuggets, verbose=True):
    for p_20 in range(nuggets // 20 + 1):
        for p_9 in range(nuggets // 9 + 1):
            for p_6 in range(nuggets // 6 + 1):
                if 20 * p_20 + 9 * p_9 + 6 * p_6 == nuggets:
                    if verbose:
                        print(f"Possible combination: (p_20, p_9, p_6) = ({p_20}, {p_9}, {p_6})")
                    return True
    if verbose:
        print("Sorry, the nuggets cannot be bought")
    return False

# Example usage
result = can_buy(60, verbose=True)
print("Result:", result)
# Out:
# Possible combination: (p_20, p_9, p_6) = (0, 0, 10)
# Result: True

# %%
def can_buy(nuggets, verbose=True):
    found_combinations = []

    for p_20 in range(nuggets // 20 + 1):
        for p_9 in range(nuggets // 9 + 1):
            for p_6 in range(nuggets // 6 + 1):
                if 20 * p_20 + 9 * p_9 + 6 * p_6 == nuggets:
                    combination = (p_20, p_9, p_6)
                    found_combinations.append(combination)
                    if verbose:
                        print(f"Possible combination: (p_20, p_9, p_6) = {combination}")

    if not found_combinations and verbose:
        print("Sorry, the nuggets cannot be bought")

    return bool(found_combinations)

# Example usage
nuggets_to_buy = 60
result = can_buy(nuggets_to_buy, verbose=True)
print(f"Result for {nuggets_to_buy} nuggets:", result)
# Out:
# Possible combination: (p_20, p_9, p_6) = (0, 0, 10)
# Possible combination: (p_20, p_9, p_6) = (0, 2, 7)
# Possible combination: (p_20, p_9, p_6) = (0, 4, 4)
# Possible combination: (p_20, p_9, p_6) = (0, 6, 1)
# Possible combination: (p_20, p_9, p_6) = (3, 0, 0)
# Result for 60 nuggets: True

# %%
import math

# Given values with uncertainties
M1 = 40e4  # Mass of M1 in kg
M1_uncertainty = 0.05e4  # Uncertainty in M1 in kg

M2 = 30e4  # Mass of M2 in kg
M2_uncertainty = 0.1e4  # Uncertainty in M2 in kg

r = 3.2  # Separation distance in meters
r_uncertainty = 0.01  # Uncertainty in separation distance in meters

# Gravitational constant (exact value)
G = 6.67430e-11  # m^3 kg^-1 s^-2

# Calculate gravitational force
F = (G * M1 * M2) / (r**2)

# Calculate partial derivatives
dF_dM1 = (G * M2) / (r**2)
dF_dM2 = (G * M1) / (r**2)
dF_dr = -2 * (G * M1 * M2) / (r**3)

# Calculate uncertainty using error propagation formula
sigma_F = math.sqrt((dF_dM1 * M1_uncertainty)**2 + (dF_dM2 * M2_uncertainty)**2 + (dF_dr * r_uncertainty)**2)

# Print the results
print("Gravitational Force:", F, "N")
print("Uncertainty in Force:", sigma_F, "N")
# Out:
# Gravitational Force: 0.7821445312499998 N
# Uncertainty in Force: 0.005625795008537251 N

# %%
import numpy as np
# Defined constant(s)
G = 6.67384e-11  # SI units

# Define values to sample from
mean_m_1 = 40.e4
sigma_m_1 = 0.05e4
mean_m_2 = 30.e4
sigma_m_2 = 0.1e4
mean_r = 3.2
sigma_r = 0.01
# Compute mean and error of force
mean_f = G * mean_m_1 * mean_m_2 / mean_r ** 2
sigma_f = mean_f * np.sqrt((sigma_m_1 / mean_m_2) ** 2
                           + (sigma_m_2 / mean_m_2) ** 2
                           + 4. * (sigma_r / mean_r) ** 2)
print(mean_f, sigma_f)
# Out:
# 0.7820906249999999 0.005691093987209795

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Given values with uncertainties
M1 = 40e4  # Mass of M1 in kg
M1_uncertainty = 0.05e4  # Uncertainty in M1 in kg

M2 = 30e4  # Mass of M2 in kg
M2_uncertainty = 0.1e4  # Uncertainty in M2 in kg

r = 3.2  # Separation distance in meters
r_uncertainty = 0.01  # Uncertainty in separation distance in meters

# Gravitational constant (exact value)
G = 6.67430e-11  # m^3 kg^-1 s^-2

# Number of Monte Carlo samples
num_samples = 1000000

# Generate random samples for M1, M2, and r
M1_samples = np.random.normal(loc=M1, scale=M1_uncertainty, size=num_samples)
M2_samples = np.random.normal(loc=M2, scale=M2_uncertainty, size=num_samples)
r_samples = np.random.normal(loc=r, scale=r_uncertainty, size=num_samples)

# Calculate gravitational force for each set of samples
force_samples = (G * M1_samples * M2_samples) / (r_samples**2)

# Calculate mean and standard deviation from standard error propagation rules
mean_force = (G * M1 * M2) / (r**2)
sigma_force = math.sqrt((dF_dM1 * M1_uncertainty)**2 + (dF_dM2 * M2_uncertainty)**2 + (dF_dr * r_uncertainty)**2)

# Plot the normalized histogram
plt.hist(force_samples, bins=100, density=True, alpha=0.7, label='Monte Carlo Samples')
plt.axvline(x=mean_force, color='red', linestyle='dashed', linewidth=2, label='Mean (Error Propagation)')
plt.axvline(x=mean_force - sigma_force, color='orange', linestyle='dashed', linewidth=2, label='Mean - 1 Sigma')
plt.axvline(x=mean_force + sigma_force, color='orange', linestyle='dashed', linewidth=2, label='Mean + 1 Sigma')

# Overlay Gaussian function
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_force, sigma_force)
plt.plot(x, p, 'k', linewidth=2)

# Set labels and title
plt.xlabel('Gravitational Force (N)')
plt.ylabel('Probability Density')
plt.title('Monte Carlo Simulation of Gravitational Force')
plt.legend()

# Show the plot
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mean_force.shape()
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
import numpy as np

def birthday_probability(n, k, N):
    matches = 0

    for _ in range(N):
        birthdays = np.random.randint(1, 366, size=n)
        unique, counts = np.unique(birthdays, return_counts=True)
        if any(count >= k for count in counts):
            matches += 1

    return matches / N

# Test case for k=2
n_k2 = 23
prob_k2 = birthday_probability(n_k2, 2, 100000)
print(f"Probability for at least 2 people sharing a birthday in a group of {n_k2}:", prob_k2)

# Solve for n such that P_2(n) = 0.5
n_solution_k2 = next(n for n in range(1, 366) if birthday_probability(n, 2, 100000) >= 0.5)
print(f"Solution for P_2(n) = 0.5: n = {n_solution_k2}")

# Solve for n such that P_3(n) = 0.5
n_solution_k3 = next(n for n in range(1, 366) if birthday_probability(n, 3, 100000) >= 0.5)
print(f"Solution for P_3(n) = 0.5: n = {n_solution_k3}")
# Out:
# Probability for at least 2 people sharing a birthday in a group of 23: 0.50675
# Solution for P_2(n) = 0.5: n = 23
# Solution for P_3(n) = 0.5: n = 88

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Define the Planck law function
def planck_law(x, A_0, T):
    return A_0 * x**3 / (np.exp(1.439 * x / T) - 1)

# Load data from the file
data = np.loadtxt("/Users/joe/python/Phys29/Phys29/data/Cobe.txt")
frequency = data[:, 0]
spectrum = data[:, 1]
uncertainty = data[:, 2]

# Perform curve fit using scipy.optimize.curve_fit
params, covariance = curve_fit(planck_law, frequency, spectrum, sigma=uncertainty)

# Extract the fitted parameters
A_0_fit, T_fit = params

# Calculate the best-fit curve using the fitted parameters
fit_curve = planck_law(frequency, A_0_fit, T_fit)

# Plot the data with error bars and the best-fit curve
plt.errorbar(frequency, spectrum, yerr=uncertainty, fmt='o', label='Data with Error Bars')
plt.plot(frequency, fit_curve, label=f'Best Fit (T = {T_fit:.2f} K)')

# Set labels and title
plt.xlabel('Frequency (1/cm)')
plt.ylabel('Spectrum (MJy/sr)')
plt.title('Cosmic Microwave Background Spectrum Fit')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Load the data
data = np.loadtxt('/Users/joe/python/Phys29/Phys29/data/radioactive_decay_data.txt')

# Extracting time, rate, and uncertainty from the data
time = data[:, 0]
rate = data[:, 1]
uncertainty = data[:, 2]

# Task 1: Plot the rate of detection versus time with error bars
plt.errorbar(time, rate, yerr=uncertainty, fmt='o', label='Data')
plt.xlabel('Time (days)')
plt.ylabel('Rate of Detection (detections per second)')
plt.title('Rate of Detection of Alpha Particles vs Time')
plt.legend()
plt.show()

# Task 2: Fit the decay model without background
def decay_model(t, R0, tau):
    return R0 * np.exp(-t / tau)

# Fit the model to the data
params, covariance = curve_fit(decay_model, time, rate, sigma=uncertainty)
fit_R0, fit_tau = params
fit_uncertainty_R0, fit_uncertainty_tau = np.sqrt(np.diag(covariance))

# Plot the best-fit curve
plt.errorbar(time, rate, yerr=uncertainty, fmt='o', label='Data')
plt.plot(time, decay_model(time, fit_R0, fit_tau), label='Fit without Background')
plt.xlabel('Time (days)')
plt.ylabel('Rate of Detection (detections per second)')
plt.title('Fit without Background')
plt.legend()
plt.show()

# Print best-fit parameters and uncertainties
print("Fit without Background:")
print(f"R0 = {fit_R0:.3f} ± {fit_uncertainty_R0:.3f}")
print(f"Tau = {fit_tau:.3f} ± {fit_uncertainty_tau:.3f}")

# Task 3: Fit the decay model with background
def decay_model_with_background(t, R0, tau, R_bkg):
    return R0 * np.exp(-t / tau) + R_bkg

# Fit the model to the data
params_with_background, covariance_with_background = curve_fit(decay_model_with_background, time, rate, sigma=uncertainty)
fit_R0_with_background, fit_tau_with_background, fit_R_bkg = params_with_background
fit_uncertainty_R0_with_background, fit_uncertainty_tau_with_background, fit_uncertainty_R_bkg = np.sqrt(np.diag(covariance_with_background))

# Plot the best-fit curve with background
plt.errorbar(time, rate, yerr=uncertainty, fmt='o', label='Data')
plt.plot(time, decay_model_with_background(time, fit_R0_with_background, fit_tau_with_background, fit_R_bkg), label='Fit with Background')
plt.axhline(y=fit_R_bkg, color='r', linestyle='--', label='Background Level')
plt.xlabel('Time (days)')
plt.ylabel('Rate of Detection (detections per second)')
plt.title('Fit with Background')
plt.legend()
plt.show()

# Print best-fit parameters and uncertainties
print("\nFit with Background:")
print(f"R0 = {fit_R0_with_background:.3f} ± {fit_uncertainty_R0_with_background:.3f}")
print(f"Tau = {fit_tau_with_background:.3f} ± {fit_uncertainty_tau_with_background:.3f}")
print(f"Background Level = {fit_R_bkg:.3f} ± {fit_uncertainty_R_bkg:.3f}")

# Task 4: Compute reduced chi^2 for both models
def compute_chi_squared(data, model, params, uncertainties):
    N = len(data)
    p = len(params)
    chi_squared = np.sum(((data - model) / uncertainties) ** 2)
    reduced_chi_squared = chi_squared / (N - p - 1)
    return reduced_chi_squared

# Compute reduced chi^2 for the models
reduced_chi_squared_without_background = compute_chi_squared(rate, decay_model(time, fit_R0, fit_tau), params, uncertainty)
reduced_chi_squared_with_background = compute_chi_squared(rate, decay_model_with_background(time, fit_R0_with_background, fit_tau_with_background, fit_R_bkg), params_with_background, uncertainty)

# Print reduced chi^2 values
print("\nReduced Chi^2 Values:")
print(f"Without Background: {reduced_chi_squared_without_background:.3f}")
print(f"With Background: {reduced_chi_squared_with_background:.3f}")
# Out:
# Fit without Background:
# R0 = 1.321 ± 0.106
# Tau = 8.883 ± 0.620
# Fit with Background:
# R0 = 2.039 ± 0.073
# Tau = 3.822 ± 0.146
# Background Level = 0.147 ± 0.005
#
# Reduced Chi^2 Values:
# Without Background: 6.804
# With Background: 1.051

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set parameters
num_walkers = 1000
num_steps = 200

# Simulate random walks
random_steps = np.random.choice([-1, 1], size=(num_steps, num_walkers))
walks = np.cumsum(random_steps, axis=0)

# Task 1: Create a two-dimensional array with walking histories
# The array 'walks' already contains the walking histories

# Task 2: Obtain arrays for <d(t)> and <d^2(t)>
mean_distances = np.mean(walks, axis=1)
mean_distances_squared = np.mean(walks**2, axis=1)
rms_distance = np.sqrt(mean_distances_squared)
# Task 3: Plot <d(t)> and <d^2(t)> as a function of time
time = np.arange(num_steps)

plt.plot(time, mean_distances, label=r'$\langle d(t) \rangle$')
plt.plot(time, rms_distance, label=r'$\sqrt{\langle d^2(t) \rangle}$')

plt.xlabel('Time Steps')
plt.ylabel('Distance')
plt.title('Random Walk Simulation')
plt.legend()
plt.show()
